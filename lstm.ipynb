# %%
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')

# Load data
data = pd.read_csv('updated_dataset.csv')

data['text'] = data['text'].astype(str).apply(lambda x: word_tokenize(x.lower()))

# Encoding labels
label_encoder = LabelEncoder()
data['label'] = label_encoder.fit_transform(data['label'])

# Split data
train_data, test_data = train_test_split(data, test_size=0.3, random_state=42)

# Vocabulary building
vocab = set(word for sentence in data['text'] for word in sentence)
word_to_ix = {word: i+1 for i, word in enumerate(vocab)}
word_to_ix['<unk>'] = len(word_to_ix) + 1
word_to_ix['<pad>'] = 0

def prepare_sequence(seq, to_ix):
    return torch.tensor([to_ix.get(word, to_ix['<unk>']) for word in seq], dtype=torch.long)

# Dataset
class TextDataset(Dataset):
    def __init__(self, dataframe, word_to_ix):
        self.dataframe = dataframe
        self.word_to_ix = word_to_ix

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        text = prepare_sequence(self.dataframe.iloc[idx]['text'], self.word_to_ix)
        label = self.dataframe.iloc[idx]['label']
        return text, label

def collate_fn(batch):
    texts, labels = zip(*batch)
    texts = pad_sequence(texts, batch_first=True, padding_value=word_to_ix['<pad>'])
    return texts, torch.tensor(labels)

train_dataset = TextDataset(train_data, word_to_ix)
test_dataset = TextDataset(test_data, word_to_ix)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, collate_fn=collate_fn)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, collate_fn=collate_fn)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\98993\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import torch.nn as nn
import torch.nn.functional as F

class EnhancedLSTMModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim, num_layers=4, bidirectional=True, dropout_rate=0.3):
        super(EnhancedLSTMModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=word_to_ix['<pad>'])
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, num_layers=num_layers, 
                            dropout=dropout_rate, bidirectional=bidirectional, batch_first=True)
        
        # Enhanced multi-layer attention mechanism
        self.attention1 = nn.Linear(hidden_dim * 2 if bidirectional else hidden_dim, hidden_dim)
        self.attention2 = nn.Linear(hidden_dim, hidden_dim // 2)
        self.attention3 = nn.Linear(hidden_dim // 2, 1)
        
        # More dense layers for deeper feature extraction
        self.fc1 = nn.Linear(hidden_dim * 2 if bidirectional else hidden_dim, hidden_dim * 4)
        self.fc2 = nn.Linear(hidden_dim * 4, hidden_dim * 2)
        self.fc3 = nn.Linear(hidden_dim * 2, output_dim)
        
        self.dropout = nn.Dropout(dropout_rate)
        self.activation = nn.ReLU()

    def forward(self, text):
        embedded = self.embedding(text)
        lstm_out, _ = self.lstm(embedded)
        
        # Multi-step attention
        attention = F.relu(self.attention1(lstm_out))
        attention = F.relu(self.attention2(attention))
        attention_weights = F.softmax(self.attention3(attention), dim=1)
        attended = torch.sum(lstm_out * attention_weights.expand_as(lstm_out), dim=1)
        
        # Deep fully connected network
        out = self.dropout(self.activation(self.fc1(attended)))
        out = self.dropout(self.activation(self.fc2(out)))
        out = self.fc3(out)
        return out
# Model instantiation
vocab_size = len(word_to_ix)  # Example vocabulary size
# embedding_dim = 128
# hidden_dim = 256
output_dim = len(label_encoder.classes_)  # Number of classes
# num_layers = 2
bidirectional = True
# dropout_rate = 0.3

# Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Instantiate and move to device
# model = EnhancedLSTMModel(vocab_size, embedding_dim, hidden_dim, output_dim).to(device)

# %%
import optuna
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import accuracy_score
from optuna.pruners import SuccessiveHalvingPruner
from optuna.samplers import TPESampler

def objective(trial):
    # Hyperparameters to tune
    num_layers = trial.suggest_int('num_layers', 1, 5)
    hidden_dim = trial.suggest_categorical('hidden_dim', [128, 256, 312])
    dropout_rate = trial.suggest_float('dropout_rate', 0.1, 0.3)
    lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
    embedding_dim = trial.suggest_int('embedding_dim', 128, 238)
    epochs = trial.suggest_int('epochs',1,7)

    # Define the model
    model = EnhancedLSTMModel(vocab_size=len(word_to_ix), embedding_dim=embedding_dim, hidden_dim=hidden_dim,
                                  output_dim=len(label_encoder.classes_), num_layers=num_layers, bidirectional=True,
                                  dropout_rate=dropout_rate).to(device)

    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()

    # Train the model
    for epoch in range(epochs):  # Reduced number of epochs for each trial
        model.train()
        for texts, labels in train_loader:
            texts, labels = texts.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(texts)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

    # Evaluate the model
    model.eval()
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for texts, labels in test_loader:
            texts, labels = texts.to(device), labels.to(device)
            outputs = model(texts)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    accuracy = accuracy_score(all_labels, all_preds)

    return accuracy

# %%
study = optuna.create_study(sampler = TPESampler(), 
                            pruner = SuccessiveHalvingPruner(),
                            direction= "maximize")
study.optimize(objective, n_trials=150)

trial = study.best_trial
print("Best Score: ", trial.value)
print("Best Params: ")
for key, value in trial.params.items():
    print("  {}: {}".format(key, value))

# Fetch the best model
best_params = study.best_trial.params
optuna.visualization.plot_param_importances(study)
# Out:
# [I 2024-05-12 02:33:05,053] A new study created in memory with name: no-name-67610bc2-9b58-4fea-9237-c16704092f2b
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# [I 2024-05-12 02:34:23,847] Trial 0 finished with value: 0.7784421460892049 and parameters: {'num_layers': 3, 'hidden_dim': 256, 'dropout_rate': 0.24457604795740787, 'lr': 0.0013430949361229742, 'embedding_dim': 170, 'epochs': 6}. Best is trial 0 with value: 0.7784421460892049.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# [I 2024-05-12 02:34:38,345] Trial 1 finished with value: 0.7947640594699418 and parameters: {'num_layers': 2, 'hidden_dim': 312, 'dropout_rate': 0.2560116986142408, 'lr': 0.0012866516605245146, 'embedding_dim': 198, 'epochs': 1}. Best is trial 1 with value: 0.7947640594699418.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# [I 2024-05-12 02:35:18,487] Trial 2 finished with value: 0.8165804783451842 and parameters: {'num_layers': 2, 'hidden_dim': 256, 'dropout_rate': 0.1899015805280937, 'lr': 0.0013349677059057107, 'embedding_dim': 221, 'epochs': 3}. Best is trial 2 with value: 0.8165804783451842.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# [I 2024-05-12 02:37:10,931] Trial 3 finished with value: 0.6690368455074337 and parameters: {'num_layers': 4, 'hidden_dim': 312, 'dropout_rate': 0.19797855994089725, 'lr': 0.011090893539367059, 'embedding_dim': 179, 'epochs': 5}. Best is trial 2 with value: 0.8165804783451842.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# [I 2024-05-12 02:37:53,500] Trial 4 finished with value: 0.6690368455074337 and parameters: {'num_layers': 4, 'hidden_dim': 312, 'dropout_rate': 0.28078823792845775, 'lr': 0.07872196500723899, 'embedding_dim': 174, 'epochs': 2}. Best is trial 2 with value: 0.8165804783451842.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# [I 2024-05-12 02:38:06,517] Trial 5 finished with value: 0.8196509372979961 and parameters: {'num_layers': 2, 'hidden_dim': 128, 'dropout_rate': 0.10023996955910089, 'lr': 0.003059919651655379, 'embedding_dim': 216, 'epochs': 2}. Best is trial 5 with value: 0.8196509372979961.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# C:\Users\98993\PycharmProjects\raicism-detection\.venv\Lib\site-packages\torch\nn\modules\rnn.py:83: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.11548326303859098 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# [I 2024-05-12 02:39:08,249] Trial 6 finished with value: 0.7797349709114415 and parameters: {'num_layers': 1, 'hidden_dim': 256, 'dropout_rate': 0.11548326303859098, 'lr': 0.0013700526802552055, 'embedding_dim': 146, 'epochs': 7}. Best is trial 5 with value: 0.8196509372979961.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# [I 2024-05-12 02:40:09,695] Trial 7 finished with value: 0.7952488687782805 and parameters: {'num_layers': 2, 'hidden_dim': 312, 'dropout_rate': 0.1330780018091416, 'lr': 0.0032256637530225143, 'embedding_dim': 128, 'epochs': 5}. Best is trial 5 with value: 0.8196509372979961.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# C:\Users\98993\PycharmProjects\raicism-detection\.venv\Lib\site-packages\torch\nn\modules\rnn.py:83: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.26366041092482917 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# [I 2024-05-12 02:40:48,601] Trial 8 finished with value: 0.6690368455074337 and parameters: {'num_layers': 1, 'hidden_dim': 128, 'dropout_rate': 0.26366041092482917, 'lr': 0.03924034042421155, 'embedding_dim': 157, 'epochs': 7}. Best is trial 5 with value: 0.8196509372979961.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# [I 2024-05-12 02:42:54,203] Trial 9 finished with value: 0.6690368455074337 and parameters: {'num_layers': 5, 'hidden_dim': 312, 'dropout_rate': 0.22765433195123627, 'lr': 0.0034574978812695846, 'embedding_dim': 190, 'epochs': 5}. Best is trial 5 with value: 0.8196509372979961.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# [I 2024-05-12 02:43:13,433] Trial 10 finished with value: 0.8010665804783452 and parameters: {'num_layers': 3, 'hidden_dim': 128, 'dropout_rate': 0.1535907660266548, 'lr': 0.010297856588356316, 'embedding_dim': 232, 'epochs': 3}. Best is trial 5 with value: 0.8196509372979961.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# [I 2024-05-12 02:43:49,451] Trial 11 finished with value: 0.8023594053005818 and parameters: {'num_layers': 2, 'hidden_dim': 256, 'dropout_rate': 0.17532403720070397, 'lr': 0.004224198120288199, 'embedding_dim': 224, 'epochs': 3}. Best is trial 5 with value: 0.8196509372979961.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# [I 2024-05-12 02:43:59,554] Trial 12 finished with value: 0.8169036845507434 and parameters: {'num_layers': 2, 'hidden_dim': 128, 'dropout_rate': 0.10205746420486213, 'lr': 0.005139171811197613, 'embedding_dim': 212, 'epochs': 1}. Best is trial 5 with value: 0.8196509372979961.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# C:\Users\98993\PycharmProjects\raicism-detection\.venv\Lib\site-packages\torch\nn\modules\rnn.py:83: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.10199451016874568 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# [I 2024-05-12 02:44:07,619] Trial 13 finished with value: 0.8135100193923723 and parameters: {'num_layers': 1, 'hidden_dim': 128, 'dropout_rate': 0.10199451016874568, 'lr': 0.006347220826546554, 'embedding_dim': 207, 'epochs': 1}. Best is trial 5 with value: 0.8196509372979961.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# [I 2024-05-12 02:44:28,538] Trial 14 finished with value: 0.7546864899806076 and parameters: {'num_layers': 3, 'hidden_dim': 128, 'dropout_rate': 0.142020543251852, 'lr': 0.019521030052976472, 'embedding_dim': 209, 'epochs': 2}. Best is trial 5 with value: 0.8196509372979961.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# [I 2024-05-12 02:44:38,516] Trial 15 finished with value: 0.8076923076923077 and parameters: {'num_layers': 2, 'hidden_dim': 128, 'dropout_rate': 0.10331669067528751, 'lr': 0.0025336783029612474, 'embedding_dim': 235, 'epochs': 1}. Best is trial 5 with value: 0.8196509372979961.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# [I 2024-05-12 02:44:55,767] Trial 16 finished with value: 0.7787653522947641 and parameters: {'num_layers': 4, 'hidden_dim': 128, 'dropout_rate': 0.16329608782981317, 'lr': 0.006247368768127469, 'embedding_dim': 209, 'epochs': 2}. Best is trial 5 with value: 0.8196509372979961.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# C:\Users\98993\PycharmProjects\raicism-detection\.venv\Lib\site-packages\torch\nn\modules\rnn.py:83: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.125603034583157 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# [I 2024-05-12 02:45:16,161] Trial 17 finished with value: 0.765513897866839 and parameters: {'num_layers': 1, 'hidden_dim': 128, 'dropout_rate': 0.125603034583157, 'lr': 0.01979282337726376, 'embedding_dim': 219, 'epochs': 4}. Best is trial 5 with value: 0.8196509372979961.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# [I 2024-05-12 02:45:28,400] Trial 18 finished with value: 0.8104395604395604 and parameters: {'num_layers': 3, 'hidden_dim': 128, 'dropout_rate': 0.2264735636627429, 'lr': 0.0021676640774204135, 'embedding_dim': 195, 'epochs': 2}. Best is trial 5 with value: 0.8196509372979961.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# [I 2024-05-12 02:45:36,063] Trial 19 finished with value: 0.8007433742727861 and parameters: {'num_layers': 2, 'hidden_dim': 128, 'dropout_rate': 0.1428795552859574, 'lr': 0.005600946146257102, 'embedding_dim': 202, 'epochs': 1}. Best is trial 5 with value: 0.8196509372979961.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# [I 2024-05-12 02:46:05,928] Trial 20 finished with value: 0.6690368455074337 and parameters: {'num_layers': 5, 'hidden_dim': 128, 'dropout_rate': 0.2991213656452359, 'lr': 0.017277728079245203, 'embedding_dim': 187, 'epochs': 4}. Best is trial 5 with value: 0.8196509372979961.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# [I 2024-05-12 02:46:43,355] Trial 21 finished with value: 0.8020361990950227 and parameters: {'num_layers': 2, 'hidden_dim': 256, 'dropout_rate': 0.18228955215662382, 'lr': 0.0016889472140032902, 'embedding_dim': 221, 'epochs': 3}. Best is trial 5 with value: 0.8196509372979961.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# [I 2024-05-12 02:47:17,196] Trial 22 finished with value: 0.8172268907563025 and parameters: {'num_layers': 2, 'hidden_dim': 256, 'dropout_rate': 0.11964969070827564, 'lr': 0.0010309043525327036, 'embedding_dim': 217, 'epochs': 3}. Best is trial 5 with value: 0.8196509372979961.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# C:\Users\98993\PycharmProjects\raicism-detection\.venv\Lib\site-packages\torch\nn\modules\rnn.py:83: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.11820572572300211 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# [I 2024-05-12 02:47:34,287] Trial 23 finished with value: 0.8125404007756949 and parameters: {'num_layers': 1, 'hidden_dim': 256, 'dropout_rate': 0.11820572572300211, 'lr': 0.0010103401026665467, 'embedding_dim': 213, 'epochs': 2}. Best is trial 5 with value: 0.8196509372979961.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# [I 2024-05-12 02:48:09,985] Trial 24 finished with value: 0.7992889463477699 and parameters: {'num_layers': 2, 'hidden_dim': 256, 'dropout_rate': 0.10673960631113552, 'lr': 0.0022427427135343716, 'embedding_dim': 237, 'epochs': 3}. Best is trial 5 with value: 0.8196509372979961.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# [I 2024-05-12 02:48:31,804] Trial 25 finished with value: 0.7676147382029735 and parameters: {'num_layers': 3, 'hidden_dim': 128, 'dropout_rate': 0.1310896609560569, 'lr': 0.004276008291761615, 'embedding_dim': 216, 'epochs': 4}. Best is trial 5 with value: 0.8196509372979961.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# [I 2024-05-12 02
. Best is trial 80 with value: 0.8267614738202973.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# [I 2024-05-12 03:22:04,152] Trial 148 finished with value: 0.8178733031674208 and parameters: {'num_layers': 2, 'hidden_dim': 128, 'dropout_rate': 0.16236740355671664, 'lr': 0.008730158659536571, 'embedding_dim': 232, 'epochs': 2}. Best is trial 80 with value: 0.8267614738202973.
# C:\Users\98993\AppData\Local\Temp\ipykernel_18496\238103859.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-3, 1e-1)
# C:\Users\98993\PycharmProjects\raicism-detection\.venv\Lib\site-packages\torch\nn\modules\rnn.py:83: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.23394271009848552 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# [I 2024-05-12 03:22:30,554] Trial 149 finished with value: 0.81060116354234 and parameters: {'num_layers': 1, 'hidden_dim': 128, 'dropout_rate': 0.23394271009848552, 'lr': 0.00328586586092955, 'embedding_dim': 225, 'epochs': 4}. Best is trial 80 with value: 0.8267614738202973.
# Best Score:  0.8267614738202973
# Best Params:
#   num_layers: 1
#   hidden_dim: 128
#   dropout_rate: 0.27589754228613206
#   lr: 0.003929971261903612
#   embedding_dim: 178
#   epochs: 2
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\PycharmProjects\raicism-detection\.venv\Lib\site-packages\optuna\visualization\_plotly_imports.py:7
#       6 with try_import() as _imports:
# ----> 7     import plotly
#       8     from plotly import __version__ as plotly_version
#
# ModuleNotFoundError: No module named 'plotly'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 14
#      12 # Fetch the best model
#      13 best_params = study.best_trial.params
# ---> 14 optuna.visualization.plot_param_importances(study)
#
# File ~\PycharmProjects\raicism-detection\.venv\Lib\site-packages\optuna\visualization\_param_importances.py:190, in plot_param_importances(study, evaluator, params, target, target_name)
#     113 def plot_param_importances(
#     114     study: Study,
#     115     evaluator: BaseImportanceEvaluator | None = None,
#    (...)
#     119     target_name: str = "Objective Value",
#     120 ) -> "go.Figure":
#     121     """Plot hyperparameter importances.
#     122
#     123     Example:
#    (...)
#     187         A :class:`plotly.graph_objects.Figure` object.
#     188     """
# --> 190     _imports.check()
#     191     importances_infos = _get_importances_infos(study, evaluator, params, target, target_name)
#     192     return _get_importances_plot(importances_infos, study)
#
# File ~\PycharmProjects\raicism-detection\.venv\Lib\site-packages\optuna\_imports.py:89, in _DeferredImportExceptionContextManager.check(self)
#      87 if self._deferred is not None:
#      88     exc_value, message = self._deferred
# ---> 89     raise ImportError(message) from exc_value
#
# ImportError: Tried to import 'plotly' but failed. Please make sure that the package is installed correctly to use this feature. Actual error: No module named 'plotly'.

# %%
best_model = EnhancedLSTMModel(vocab_size=len(word_to_ix), embedding_dim=best_params['embedding_dim'],
                                   hidden_dim=best_params['hidden_dim'], output_dim=len(label_encoder.classes_),
                                   num_layers=best_params['num_layers'], bidirectional=True,
                                   dropout_rate=best_params['dropout_rate']).to(device)
print(best_params)
# Out:
# {'num_layers': 1, 'hidden_dim': 128, 'dropout_rate': 0.27589754228613206, 'lr': 0.003929971261903612, 'embedding_dim': 178, 'epochs': 2}
# C:\Users\98993\PycharmProjects\raicism-detection\.venv\Lib\site-packages\torch\nn\modules\rnn.py:83: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.27589754228613206 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "

# %%
optimizer = optim.Adam(best_model.parameters(), lr=best_params['lr'])
criterion = nn.CrossEntropyLoss()
for epoch in range( best_params['epochs']):  # Reduced number of epochs for each trial
        best_model.train()
        for texts, labels in train_loader:
            texts, labels = texts.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = best_model(texts)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

    # Evaluate the model
        best_model.eval()
        all_preds = list()
        all_labels = list()
        with torch.no_grad():
            for texts, labels in test_loader:
                texts, labels = texts.to(device), labels.to(device)
                outputs = best_model(texts)
                _, preds = torch.max(outputs, 1)
                all_preds.extend(preds.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())
        accuracy = accuracy_score(all_labels, all_preds)

        print(f'The Epoch {epoch}  ','The accuracy is  ' ,accuracy)
# Out:
# The Epoch 0   The accuracy is   0.811732385261797
# The Epoch 1   The accuracy is   0.8211053652230123
